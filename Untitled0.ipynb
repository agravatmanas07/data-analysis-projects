# %% [markdown]
# <a href="https://colab.research.google.com/github/agravatmanas07/data-analysis-projects/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
path_data = '/content/RealEstate_Paris_cleaned_17_12_2019.csv'
df_housing = pd.read_csv(path_data)
print('Data Columns: {}'.format(df_housing.columns))
print('Data shape: {}'.format(df_housing.shape))
# Out:
# Data Columns: Index(['Unnamed: 0', 'index', 'id_mutation', 'date_mutation',
#        'nature_mutation', 'valeur_fonciere', 'adresse_numero',
#        'adresse_suffixe', 'adresse_nom_voie', 'adresse_code_voie',
#        'code_postal', 'code_commune', 'nom_commune', 'code_departement',
#        'lot1_surface_carrez', 'lot2_surface_carrez', 'lot3_surface_carrez',
#        'lot4_surface_carrez', 'lot5_surface_carrez', 'nombre_lots',
#        'code_type_local', 'type_local', 'surface_reelle_bati',
#        'nombre_pieces_principales', 'code_nature_culture', 'nature_culture',
#        'surface_terrain', 'longitude', 'latitude', 'année', 'mois',
#        'duplicated'],
#       dtype='object')
# Data shape: (21121, 32)
# <ipython-input-5-4b1eee50058d>:5: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_housing = pd.read_csv(path_data)

# %%
df_housing
# Out:
#        Unnamed: 0    index   id_mutation date_mutation nature_mutation  \
# 0          752156  2289411   2018-987606    2018-01-04           Vente
# 1          752157  2289412   2018-987607    2018-01-09           Vente
# 2          752158  2289415   2018-987609    2018-01-03           Vente
# 3          752159  2289416   2018-987610    2018-01-03           Vente
# 4          752160  2289417   2018-987611    2018-01-05           Vente
# ...           ...      ...           ...           ...             ...
# 21116      776418  2338996  2018-1020920    2018-12-31           Vente
# 21117      776420  2338998  2018-1020922    2018-12-31           Vente
# 21118      776421  2338999  2018-1020923    2018-12-31           Vente
# 21119      776422  2339000  2018-1020924    2018-12-27           Vente
# 21120      776423  2339001  2018-1020925    2018-12-28           Vente
#
#        valeur_fonciere  adresse_numero adresse_suffixe  \
# 0           1202000.00            10.0             NaN
# ...

# %%
fig = plt.figure(figsize=(8,8))
#ax = fig.subplots(1,1)
ax = fig.add_subplot()
ax.hist(df_housing[df_housing['code_commune']==75113]['valeur_fonciere']);

ax.set_title('Prix Immobilier Paris 13eme')
#ax.legend(['legend'])
# Out:
# Text(0.5, 1.0, 'Prix Immobilier Paris 13eme')

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(x='nom_commune', y='valeur_fonciere', data=df)
plt.title('Apartment Prices by Arrondissement')
plt.xlabel('Arrondissement')
plt.ylabel('Price (€)')
plt.xticks(rotation=45)
plt.show()

# %%
sold_items_per_month = df.groupby('mois').size().reset_index(name='number_of_sold_items')

sold_items_per_arrondissement = df.groupby('nom_commune').size().reset_index(name='number_of_sold_items')

print("Number of sold items per month:")
print(sold_items_per_month)
# Out:
# Number of sold items per month:
#     mois  number_of_sold_items
# 0      1                  1787
# 1      2                  1809
# 2      3                  2248
# 3      4                  1849
# 4      5                  1905
# 5      6                  2437
# 6      7                  2695
# 7      8                  1128
# 8      9                  1916
# 9     10                  1909
# 10    11                   871
# 11    12                   567

# %%
avg  = df.groupby('nom_commune')['valeur_fonciere']
print("least expensive regions:")
print(avg.mean().sort_values(ascending=False))
# Out:
# least expensive regions:
# nom_commune
# Paris 7e Arrondissement     888308.114638
# Paris 8e Arrondissement     814249.109375
# Paris 6e Arrondissement     735681.828601
# Paris 16e Arrondissement    715338.985768
# Paris 4e Arrondissement     654794.729859
# Paris 3e Arrondissement     539514.023106
# Paris 1er Arrondissement    534706.697677
# Paris 5e Arrondissement     533687.514142
# Paris 9e Arrondissement     514750.732655
# Paris 17e Arrondissement    500917.720328
# Paris 2e Arrondissement     480642.940820
# Paris 15e Arrondissement    462304.375000
# Paris 10e Arrondissement    416801.044713
# Paris 14e Arrondissement    408370.953509
# Paris 11e Arrondissement    380974.049129
# Paris 12e Arrondissement    373872.856012
# Paris 13e Arrondissement    350509.977853
# Paris 18e Arrondissement    337322.292603
# Paris 19e Arrondissement    326484.059105
# Paris 20e Arrondissement    317228.764447
# Name: valeur_fonciere, dtype: float64

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='surface_reelle_bati', y='valeur_fonciere', data=df, alpha=0.5)

plt.title('Relationship between Price and Surface')
plt.xlabel('Surface Area (m²)')
plt.ylabel('Price (€)')


sns.regplot(x='surface_reelle_bati', y='valeur_fonciere', data=df, scatter=False, color='red')

plt.tight_layout()
plt.show()
